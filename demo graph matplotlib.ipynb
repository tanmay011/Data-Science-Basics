# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.linspace(0,10,20)
y = x * x
z = x+y

print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x11D88BC8>]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.linspace(0,10,20)
y = x * x
z = x+y

print(plt.plot(x,y))
# Out:
# [<matplotlib.lines.Line2D object at 0x11E1E310>]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.linspace(0,10,20)
y = x * x
z = x+y

print(plt.plot(x,x))
# Out:
# [<matplotlib.lines.Line2D object at 0x139C1298>]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.linspace(0,10,20)
y = x * x
z = x+y

print(plt.plot(x,y,z))
# Out:
# [<matplotlib.lines.Line2D object at 0x13B52988>, <matplotlib.lines.Line2D object at 0x13B529A0>]

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.linspace(0,10,20)
y = x * x
z = x+y

print(plt.plot(x,y))
print(plt.xlabel("x axis"))
print(plt.xlabel("y axis"))
print(plt.title("demo graph"))
# Out:
# [<matplotlib.lines.Line2D object at 0x13DD5A60>]
# Text(0.5, 0, 'x axis')
# Text(0.5, 0, 'y axis')
# Text(0.5, 1.0, 'demo graph')

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

x = np.linspace(0,10,20)
y = x * x
z = x+y

print(plt.plot(x,y))
print(plt.xlabel("x axis"))
print(plt.ylabel("y axis"))
print(plt.title("demo graph"))
# Out:
# [<matplotlib.lines.Line2D object at 0x14989D78>]
# Text(0.5, 0, 'x axis')
# Text(0, 0.5, 'y axis')
# Text(0.5, 1.0, 'demo graph')
