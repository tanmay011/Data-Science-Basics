# %%
import pandas as pd
import seaborn as sns
import numpy as np


df1 = sns.load_dataset("tips")
df2 = pd.read_csv("188.iris.csv")

# %%
df1
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
df2
# Out:
#      SepalLength  SepalWidth  PetalLength  PetalWidth            Name
# 0            5.1         3.5          1.4         0.2     Iris-setosa
# 1            4.9         3.0          1.4         0.2     Iris-setosa
# 2            4.7         3.2          1.3         0.2     Iris-setosa
# 3            4.6         3.1          1.5         0.2     Iris-setosa
# 4            5.0         3.6          1.4         0.2     Iris-setosa
# ..           ...         ...          ...         ...             ...
# 145          6.7         3.0          5.2         2.3  Iris-virginica
# 146          6.3         2.5          5.0         1.9  Iris-virginica
# 147          6.5         3.0          5.2         2.0  Iris-virginica
# 148          6.2         3.4          5.4         2.3  Iris-virginica
# 149          5.9         3.0          5.1         1.8  Iris-virginica
#
# [150 rows x 5 columns]

# %%
x1 = np.random.rand(100,5)
x2 = np.random.rand(10,5)
df3 = pd.DataFrame(x1, columns = ["a","b","c","d","e"])

# %%
df3
# Out:
#            a         b         c         d         e
# 0   0.764541  0.874131  0.570892  0.649117  0.389073
# 1   0.841112  0.150079  0.641152  0.553453  0.621950
# 2   0.109488  0.142462  0.458221  0.687158  0.331119
# 3   0.604952  0.257877  0.637594  0.599074  0.111582
# 4   0.560882  0.539457  0.395942  0.377090  0.128875
# ..       ...       ...       ...       ...       ...
# 95  0.530214  0.280038  0.962737  0.104531  0.869294
# 96  0.891859  0.439149  0.674344  0.068117  0.575940
# 97  0.964560  0.296154  0.216533  0.018110  0.782585
# 98  0.387292  0.894996  0.939140  0.015367  0.548497
# 99  0.966048  0.911683  0.095330  0.671420  0.494555
#
# [100 rows x 5 columns]

# %%
df4 = pd.DataFrame(x2, columns = ["a","b","c","d","e"])

# %%
df4
# Out:
#           a         b         c         d         e
# 0  0.504330  0.857769  0.181455  0.733982  0.942899
# 1  0.117761  0.562349  0.623550  0.279983  0.974055
# 2  0.471037  0.366773  0.865498  0.506639  0.956556
# 3  0.043751  0.107638  0.490814  0.653878  0.497609
# 4  0.634354  0.766281  0.431937  0.103707  0.602263
# 5  0.018640  0.555870  0.687983  0.100930  0.626514
# 6  0.949203  0.332406  0.640857  0.550346  0.955869
# 7  0.520365  0.545250  0.408717  0.678140  0.775306
# 8  0.593121  0.797171  0.315596  0.079003  0.632192
# 9  0.869996  0.638678  0.951342  0.153325  0.710015

# %%
df3.plot.scatter(x ="a", y = "b")

# %%
df4.plot.scatter(x ="a", y = "b")

# %%
df1.plot.scatter(x ="total_bill", y = "tip")

# %%
df4.plot.line()

# %%
df3.plot.kde()

# %%
df3["a"].plot.kde()

# %%
df4["a"].plot.kde()

# %%
df1["tip"].plot.line()

# %%
df4.plot.hist()

# %%
df2.plot.bar()

# %%
df4.plot.area()

# %%
df4.plot.box(color="g")

# %%
df3.plot.hexbin(x="a",y="b",gridsize=10)
