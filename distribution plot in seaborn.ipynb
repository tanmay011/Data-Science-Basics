# %%
import seaborn as sns
import numpy as np
import pandas as pd

tips = sns.load_dataset("tips")
print(tips)

tips.head()

#POINTPLOT IN SEABORN PLOTS ONLY ON ONE PARAMETER EG- TOTAL_BILL
sns.kdeplot(tips["total_bill"])

sns.distplot(tips["total_bill"], kde =False)

#DISTRIBUTION PLOTS ARE PLOTS WHICH ARE PLOTTED ON 2 PARAMETER THEY CAN BE DIRECTLY PLOTTED 
#OR EVEN JOINTLY PLOTTED
sns.jointplot(x="total_bill", y="tip", data=tips, kind=hex)
# Out:
# total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Tanmay Naik\Documents\data science lib python\seaborn tut.py in <module>
#      <a href='file://c:\Users\Tanmay Naik\Documents\data science lib python\seaborn tut.py?line=15'>16</a> #DISTRIBUTION PLOTS ARE PLOTS WHICH ARE PLOTTED ON 2 PARAMETER THEY CAN BE DIRECTLY PLOTTED
#      <a href='file://c:\Users\Tanmay Naik\Documents\data science lib python\seaborn tut.py?line=16'>17</a> #OR EVEN JOINTLY PLOTTED
# ---> <a href='file://c:\Users\Tanmay Naik\Documents\data science lib python\seaborn tut.py?line=17'>18</a> sns.jointplot(x="total_bill", y="tip", data=tips, kind=hex)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2293         grid.plot_marginals(distplot, **marginal_kws)
#    2294
# -> 2295     elif kind.startswith("hex"):
#    2296
#    2297         x_bins = min(_freedman_diaconis_bins(grid.x), 50)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'startswith'

# %%
sns.jointplot(x="total_bill", y="tip", data=tips, kind=hex)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Tanmay Naik\Documents\data science lib python\seaborn tut.py in <module>
# ----> 1 sns.jointplot(x="total_bill", y="tip", data=tips, kind=hex)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2293         grid.plot_marginals(distplot, **marginal_kws)
#    2294
# -> 2295     elif kind.startswith("hex"):
#    2296
#    2297         x_bins = min(_freedman_diaconis_bins(grid.x), 50)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'startswith'

# %%
import seaborn as sns
import numpy as np
import pandas as pd

tips = sns.load_dataset("tips")
print(tips)

tips.head()
# Out:
# total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.jointplot(x= "total_bill", y= "tip", data= tips, kind=hex)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Tanmay Naik\Documents\data science lib python\seaborn tut.py in <module>
# ----> 1 sns.jointplot(x= "total_bill", y= "tip", data= tips, kind=hex)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2293         grid.plot_marginals(distplot, **marginal_kws)
#    2294
# -> 2295     elif kind.startswith("hex"):
#    2296
#    2297         x_bins = min(_freedman_diaconis_bins(grid.x), 50)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'startswith'

# %%
sns.jointplot(x= "total_bill", y= "tip", data= tips)

# %%
sns.jointplot(x= "total_bill", y= "tip", data= tips, kind=hex)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\Tanmay Naik\Documents\data science lib python\seaborn tut.py in <module>
# ----> 1 sns.jointplot(x= "total_bill", y= "tip", data= tips, kind=hex)
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\seaborn\axisgrid.py in jointplot(x, y, data, kind, stat_func, color, height, ratio, space, dropna, xlim, ylim, joint_kws, marginal_kws, annot_kws, **kwargs)
#    2293         grid.plot_marginals(distplot, **marginal_kws)
#    2294
# -> 2295     elif kind.startswith("hex"):
#    2296
#    2297         x_bins = min(_freedman_diaconis_bins(grid.x), 50)
#
# AttributeError: 'builtin_function_or_method' object has no attribute 'startswith'

# %%
sns.jointplot(x= "total_bill", y= "tip", data= tips, kind= "kde")

# %%
sns.jointplot(x= "total_bill", y= "tip", data= tips, kind= "hex")
